# %%
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# list of salaries and years

salaries_and_tenures = [(83000, 8.7), (88000, 8.1),
(48000, 0.7), (76000, 6),
(69000, 6.5), (76000, 7.5),
(60000, 2.5), (83000, 10),
(48000, 1.9), (63000, 4.2)]

# seperate the list

salaries = [salary for salary , tenure in salaries_and_tenures]
tenures = [tenure for salary, tenure in salaries_and_tenures]

print(salaries)
print(tenures)
# Out:
# [83000, 88000, 48000, 76000, 69000, 76000, 60000, 83000, 48000, 63000]
# [8.7, 8.1, 0.7, 6, 6.5, 7.5, 2.5, 10, 1.9, 4.2]

# %%
# simple plot
plt.scatter(tenures, salaries)

# %%
# customise the plot
plt.scatter(tenures, salaries)
plt.title('Plot of data scientist salaries in regards to years of works')
plt.xlabel('Years of Experience')
plt.ylabel('salary')

plt.show()

# %%
# lets represent the fact that longer tenure = higher salary in a nicer format

salary_by_tenure = defaultdict(list)

for salary, tenure in salaries_and_tenures:
    salary_by_tenure[tenure].append(salary)

average_salary_by_tenure = {
    tenure : sum(salaries) / len(salaries)
    for tenure, salaries in salary_by_tenure.items()
}

print(salary_by_tenure)
# Out:
# defaultdict(<class 'list'>, {8.7: [83000], 8.1: [88000], 0.7: [48000], 6: [76000], 6.5: [69000], 7.5: [76000], 2.5: [60000], 10: [83000], 1.9: [48000], 4.2: [63000]})

# %%
def tenure_bucket(tenure):
    if tenure < 2:
        return "less than two"
    elif tenure < 5:
        return "between two and five"
    else:
        return "more than five"
    
print(tenure_bucket(tenures[2]))
# Out:
# less than two

# %%
# keys are tenure buckets, values are lists of salaries for that bucket
salary_by_tenure_bucket = defaultdict(list)
for salary, tenure in salaries_and_tenures:
    bucket = tenure_bucket(tenure)
    salary_by_tenure_bucket[bucket].append(salary)

print(salary_by_tenure_bucket)
# Out:
# defaultdict(<class 'list'>, {'more than five': [83000, 88000, 76000, 69000, 76000, 83000], 'less than two': [48000, 48000], 'between two and five': [60000, 63000]})

# %%
average_salary_by_bucket = {
    tenure_bucket : sum(salaries) / len(salaries)
    for tenure_bucket, salaries in salary_by_tenure_bucket.items()
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 3
#       1 average_salary_by_bucket = {
#       2     tenure_bucket : sum(salaries) / len(salaries)
# ----> 3     for tenure_bucket, salaries in salary_by_tenure_bucket.iteritems()
#       4 }
#
# AttributeError: 'collections.defaultdict' object has no attribute 'iteritems'
